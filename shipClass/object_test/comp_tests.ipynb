# %% [markdown]
# ### initialization of a component

# %%
from shipClass.Component import Component

c1 = Component("Engine" , 200)

# %% [markdown]
# ### plotting various shapes using stats originally

# %%
betas = [0.2, 1.0, 5]
for beta in betas:
    comp = Component("Engine", shape=beta, scale= 20)

    comp.plotDistros()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 betas = [0.2, 1.0, 5]
#       2 for beta in betas:
# ----> 3     comp = Component("Engine", shape=beta, scale= 20)
#       5     comp.plotDistros()
#
# TypeError: Component.__init__() missing 1 required positional argument: 'MTTF'

# %% [markdown]
# ### initializing markov chain

# %%
from shipClass.Component import Component

c1 = Component("Engine")

states = ["Working", "Failed"]
transitionMatrix = [[0.5, 0.5], [0.5, 0]]

c1.simulate(10)
# Out:
# ['Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working',
#  'Working']

# %% [markdown]
# ### checking the auto definition of transition matrices

# %%
import numpy as np
from shipClass.Component import Component

# simulate 1000 components and determine the MTTF of the Markov Chains
num_comps = 1
steps = 300

failure_times = []

states = {0: "Working", 1: "Failed"}

for i in range(num_comps): 
    comp = Component('Test_Component', 200)
    comp.simulate(steps)    
    # failure_times.append(comp.mC_model.failure_time)
    
print("Mean Time to Failure: ", np.mean(failure_times))
# Out:
# 2.9832794003665666
# Mean Time to Failure:  nan
# C:\Users\adware\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\fromnumeric.py:3904: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\adware\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\_methods.py:147: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
print(comp.mC_model.history[-10])
# Out:
# Broken
