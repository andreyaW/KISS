# %% [markdown]
# Testing Makov chain class and its functions

# %%
import sys
sys.path.append('..')
print(sys.path)
# Out:
# ['C:\\Users\\adware\\AppData\\Local\\Programs\\Python\\Python313\\python313.zip', 'C:\\Users\\adware\\AppData\\Local\\Programs\\Python\\Python313\\DLLs', 'C:\\Users\\adware\\AppData\\Local\\Programs\\Python\\Python313\\Lib', 'C:\\Users\\adware\\AppData\\Local\\Programs\\Python\\Python313', '\\\\engin-storage.m.storage.umich.edu\\engin-storage\\adware\\windat.v2\\Documents\\KISS_env2', '', '\\\\engin-storage.m.storage.umich.edu\\engin-storage\\adware\\windat.v2\\Documents\\KISS_env2\\Lib\\site-packages', '\\\\engin-storage.m.storage.umich.edu\\engin-storage\\adware\\windat.v2\\Documents\\KISS_env2\\Lib\\site-packages\\win32', '\\\\engin-storage.m.storage.umich.edu\\engin-storage\\adware\\windat.v2\\Documents\\KISS_env2\\Lib\\site-packages\\win32\\lib', '\\\\engin-storage.m.storage.umich.edu\\engin-storage\\adware\\windat.v2\\Documents\\KISS_env2\\Lib\\site-packages\\Pythonwin', '..']

# %%
from shipClass.MarkovChain import MarkovChain

import numpy as np

states = {0: 'Broken', 
          1: 'Operational'}

transition_matrix = np.array([[ 1, 0],
                             [0.05, 0.95]])

test_mc  = MarkovChain(states, transition_matrix)
test_mc.simulate(30)
test_mc.plotHistory()

# %%
from shipClass.MarkovChain import MarkovChain

import numpy as np

states = {0: 'Broken', 
          1: 'Degraded',
          2: 'Operational'}

transition_matrix = np.array([[ 1, 0, 0],
                              [0.10, 0.90, 0],
                              [0.05, 0.05, 0.90]])

test_mc  = MarkovChain(states, transition_matrix)
test_mc.simulate(30)
test_mc.plotHistory()
test_mc.drawChain()
